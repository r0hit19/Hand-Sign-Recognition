# %%
# CREATING X, Y
from tensorflow.keras import models, layers
import os
import cv2
import numpy as np

TRAIN_DIR = "R:/AA_Sign_Language/CNN+Image/Gestures"

num_classes=24
IMG_SIZE = 100
def vectorize_data(TRAIN_DIR):
    result = []
    labels = []
    for label in os.listdir(TRAIN_DIR):
        path=""
        path=os.path.join(TRAIN_DIR, label)
        for img in os.listdir(path):
            path2=""
            path2 = os.path.join(path, img)
            i = cv2.imread(path2)
            #i = cv2.cvtColor(i, cv2.COLOR_BGR2GRAY)
            
            i = cv2.resize(cv2.imread(path2, cv2.IMREAD_GRAYSCALE), (IMG_SIZE, IMG_SIZE))
            
            
            result.append(i)
            labels.append(label)
    
    return result, labels

x, y =vectorize_data(TRAIN_DIR)
x_train = np.array(x)
y_train = np.array(y)

x_train = np.expand_dims(x_train, axis=-1)
x_train.shape
# Out:
# (682, 100, 100, 1)

# %%
from tensorflow.keras.utils import to_categorical
dictonary = {'A':0, 'B':1, 'C':2, 'D':3, 'E':4, 'F':5, 'G':6, 'H':7, 'I':8, 'K':9, 'L':10, 'M':11, 'N':12, 'O':13, 'P':14, 
            'Q':15, 'R':16, 'S':17, 'T':18, 'U':19, 'V':20, 'W':21, 'X':22, 'Y':23}
num_classes=24
keys, inv = np.unique(y_train, return_inverse=True)
vals = np.array([dictonary[key] for key in keys])
y_train_new = vals[inv]
y_train_new_cat = to_categorical(y_train_new, num_classes)


'''
keys, inv = np.unique(y_test, return_inverse=True)
vals = np.array([dictonary[key] for key in keys])
y_test_new = vals[inv]
y_test_new_cat = to_categorical(y_test_new,num_classes=24)
'''
# SHUFFLE
def unison_shuffled_copies(a, b):
    p = np.random.permutation(len(a))
    return a[p], b[p]
x_new,y_new = unison_shuffled_copies(x_train,y_train_new_cat)

# %%
# MODEL CREATION
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import SGD
IMG_SIZE = 100

num_classes = 24
model = Sequential()

model.add(Conv2D(16, (2,2), input_shape=(IMG_SIZE, IMG_SIZE, 1), activation='relu'))
#model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2) ))

model.add(Conv2D(32, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2) ))

model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2) ))

model.add(Flatten())
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.compile(optimizer=SGD(0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
#np.expand_dims(i, axis=0)

# %%
history=model.fit(x_new, y_new, epochs = 30, validation_split = 0.1, shuffle = True, batch_size = 2)
# Out:
# Epoch 1/30
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0849 - accuracy: 0.9755 - val_loss: 1.3827 - val_accuracy: 0.6812
# Epoch 2/30
# 307/307 [==============================] - 8s 25ms/step - loss: 0.1050 - accuracy: 0.9657 - val_loss: 1.4693 - val_accuracy: 0.6667
# Epoch 3/30
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0551 - accuracy: 0.9869 - val_loss: 1.3517 - val_accuracy: 0.7101
# Epoch 4/30
# 307/307 [==============================] - 8s 25ms/step - loss: 0.0573 - accuracy: 0.9869 - val_loss: 1.3387 - val_accuracy: 0.7101
# Epoch 5/30
# 307/307 [==============================] - 8s 26ms/step - loss: 0.0455 - accuracy: 0.9918 - val_loss: 1.3075 - val_accuracy: 0.7101
# Epoch 6/30
# 307/307 [==============================] - 8s 26ms/step - loss: 0.0622 - accuracy: 0.9755 - val_loss: 1.4048 - val_accuracy: 0.6667
# Epoch 7/30
# 307/307 [==============================] - 8s 27ms/step - loss: 0.0584 - accuracy: 0.9804 - val_loss: 1.5038 - val_accuracy: 0.6232
# Epoch 8/30
# 307/307 [==============================] - 8s 27ms/step - loss: 0.0716 - accuracy: 0.9772 - val_loss: 1.5277 - val_accuracy: 0.6667
# Epoch 9/30
# 307/307 [==============================] - 8s 27ms/step - loss: 0.0650 - accuracy: 0.9788 - val_loss: 1.5272 - val_accuracy: 0.6957
# Epoch 10/30
# 307/307 [==============================] - 8s 26ms/step - loss: 0.0454 - accuracy: 0.9853 - val_loss: 1.4948 - val_accuracy: 0.7101
# Epoch 11/30
# 307/307 [==============================] - 8s 26ms/step - loss: 0.0408 - accuracy: 0.9918 - val_loss: 1.3925 - val_accuracy: 0.6812
# Epoch 12/30
# 307/307 [==============================] - 8s 26ms/step - loss: 0.0541 - accuracy: 0.9918 - val_loss: 1.5734 - val_accuracy: 0.6957
# Epoch 13/30
# 307/307 [==============================] - 8s 26ms/step - loss: 0.0535 - accuracy: 0.9837 - val_loss: 1.4567 - val_accuracy: 0.7101
# Epoch 14/30
# 307/307 [==============================] - 8s 26ms/step - loss: 0.0501 - accuracy: 0.9853 - val_loss: 1.5012 - val_accuracy: 0.6667
# Epoch 15/30
# 307/307 [==============================] - 8s 26ms/step - loss: 0.0282 - accuracy: 0.9967 - val_loss: 1.4515 - val_accuracy: 0.7101
# Epoch 16/30
# 307/307 [==============================] - 8s 26ms/step - loss: 0.0302 - accuracy: 0.9918 - val_loss: 1.3804 - val_accuracy: 0.7246
# Epoch 17/30
# 307/307 [==============================] - 8s 26ms/step - loss: 0.0485 - accuracy: 0.9821 - val_loss: 1.3345 - val_accuracy: 0.7391
# Epoch 18/30
# 307/307 [==============================] - 8s 26ms/step - loss: 0.0469 - accuracy: 0.9886 - val_loss: 1.5146 - val_accuracy: 0.6812
# Epoch 19/30
# 307/307 [==============================] - 8s 26ms/step - loss: 0.0502 - accuracy: 0.9837 - val_loss: 1.3623 - val_accuracy: 0.6957
# Epoch 20/30
# 307/307 [==============================] - 8s 26ms/step - loss: 0.0266 - accuracy: 0.9951 - val_loss: 1.3856 - val_accuracy: 0.7391
# Epoch 21/30
# 307/307 [==============================] - 8s 26ms/step - loss: 0.0258 - accuracy: 0.9984 - val_loss: 1.3942 - val_accuracy: 0.7391
# Epoch 22/30
# 307/307 [==============================] - 8s 26ms/step - loss: 0.0386 - accuracy: 0.9886 - val_loss: 1.3987 - val_accuracy: 0.7391
# Epoch 23/30
# 307/307 [==============================] - 8s 26ms/step - loss: 0.0283 - accuracy: 0.9935 - val_loss: 1.4446 - val_accuracy: 0.6957
# Epoch 24/30
# 307/307 [==============================] - 8s 26ms/step - loss: 0.0193 - accuracy: 0.9967 - val_loss: 1.4090 - val_accuracy: 0.6812
# Epoch 25/30
# 307/307 [==============================] - 8s 26ms/step - loss: 0.0446 - accuracy: 0.9853 - val_loss: 1.4571 - val_accuracy: 0.7101
# Epoch 26/30
# 307/307 [==============================] - 8s 27ms/step - loss: 0.0450 - accuracy: 0.9869 - val_loss: 1.3581 - val_accuracy: 0.7101
# Epoch 27/30
# 307/307 [==============================] - 8s 26ms/step - loss: 0.0263 - accuracy: 0.9918 - val_loss: 1.3968 - val_accuracy: 0.7246
# Epoch 28/30
# 307/307 [==============================] - 8s 27ms/step - loss: 0.0414 - accuracy: 0.9902 - val_loss: 1.3913 - val_accuracy: 0.6812
# Epoch 29/30
# 307/307 [==============================] - 8s 26ms/step - loss: 0.0486 - accuracy: 0.9869 - val_loss: 1.3845 - val_accuracy: 0.6667
# Epoch 30/30
# 307/307 [==============================] - 8s 26ms/step - loss: 0.0369 - accuracy: 0.9837 - val_loss: 1.2727 - val_accuracy: 0.7101

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc))

fig = plt.figure(figsize=(14,7))
plt.plot(epochs, acc, 'r', label="Training Accuracy")
plt.plot(epochs, val_acc, 'b', label="Validation Accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
fig = plt.figure(figsize=(14,7))
plt.plot(epochs, loss, 'r', label="Training Loss")
plt.plot(epochs, val_loss, 'b', label="Validation Loss")
plt.legend(loc='upper right')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')
